# %%
import pandas as pd
import os

# %%
pwd = os.getcwd()
pwd

# %%
dataset = pd.read_excel(pwd + "\\Data-survey_monkey_edited.xlsx", sheet_name="Edited_data")

# %%
datasetModified = dataset.copy()
datasetModified.columns

# %%
datasetModified1=datasetModified.copy()
datasetModified1

# %%
datasetModified1.drop(datasetModified1.columns[[1,2,3,4,5,6]], axis=1,inplace=True)
datasetModified1

# %%
id_vars = list(datasetModified1)[0:8]
value_vars = list(datasetModified1)[8:]

# %%
dataMelt = datasetModified1.melt(id_vars=id_vars, value_vars=value_vars,var_name="Question + Subquestion",value_name="Answer")
dataMelt

# %%
questions = pd.read_excel(pwd + "\\Data-survey_monkey_edited.xlsx", sheet_name="questions")

# %%
questions

# %%
questionsmod=questions.copy()
questionsmod =questions.drop(columns=["Raw_Question","Subquestion","Raw_Sub-Question"])
questionsmod

# %%
questionsmod

# %%
merge1 = pd.merge(left=dataMelt, right=questionsmod, how="left" , left_on="Question + Subquestion" , right_on="Question + Subquestion")
merge1
respondents.rename(columns={"Respondents ID":"Respondents"},inplace=True)

# %%
respondents = merge1[merge1["Answer"].notna()]
respondents1 = respondents.groupby("Question")["Respondent ID"].nunique().reset_index()
merge2 = pd.merge(left=respondents, right=respondents1, how="left" , left_on="Question" , right_on="Question")
merge2
# Out:
#       Respondent ID_x Identify which division you work in. - Response  \
# 0          2658722536                                         Finance
# 1          4044163394                                  Infrastructure
# 2          5535865599                                  Infrastructure
# 3          3399511781                                  Infrastructure
# 4          9860597462                                  Infrastructure
# ...               ...                                             ...
# 9659       9735550076                                          People
# 9660       7325851635                                  Infrastructure
# 9661       3370365802            Port Security & Emergency Operations
# 9662       7940065082                                  Infrastructure
# 9663       5157705612                                         Finance
#
#      Identify which division you work in. - Other (please specify)  \
# 0                                                   NaN
# ...
